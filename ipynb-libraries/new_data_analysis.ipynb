# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
# Column names based on Binance Kline data format
column_names = ['Open time', 'Open', 'High', 'Low', 'Close', 'Volume', 
                'Close time', 'Quote asset volume', 'Number of trades', 
                'Taker buy base asset volume', 'Taker buy quote asset volume', 'Ignore']

# Load the CSV file
file_path = './Merged_CSV.csv'  # Update the path if necessary
df = pd.read_csv(file_path, names=column_names)

df.info()
df.plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Open time                     324 non-null    int64
#  1   Open                          324 non-null    float64
#  2   High                          324 non-null    float64
#  3   Low                           324 non-null    float64
#  4   Close                         324 non-null    float64
#  5   Volume                        324 non-null    float64
#  6   Close time                    324 non-null    int64
#  7   Quote asset volume            324 non-null    float64
#  8   Number of trades              324 non-null    int64
#  9   Taker buy base asset volume   324 non-null    float64
#  10  Taker buy quote asset volume  324 non-null    float64
#  11  Ignore                        324 non-null    int64
# dtypes: float64(8), int64(4)
# memory usage: 30.5 KB
# <Axes: >
